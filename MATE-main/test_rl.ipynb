# %%
import torch
import torch.nn as nn
from tqdm.notebook import tqdm_notebook as tqdm
# from tqdm import tqdm
import gym_agent as ga

# %%
total_timesteps = 200000
max_episode_steps = 500
chkpt_dir = "checkpoints/"

env_id = 'LunarLander-v3'

# %% [markdown]
# # DQN

# %%
class DeepQNetwork(nn.Module):
    def __init__(self, n_inp: int, n_out: int, features: list[int] = [64, 64]):
        super().__init__()

        layers = [n_inp] + features + [n_out]

        self.net = nn.Sequential()

        for i in range(len(layers)-1):
            self.net.append(nn.Linear(layers[i], layers[i+1]))

            if i < len(layers)-2:
                self.net.append(nn.ReLU())

    def forward(self, X):
        return self.net(X)

# %%
def net_factory():
    return DeepQNetwork(
        n_inp=8,
        n_out=4,
        features=[256, 256]
    )

# %%
dqn_policy = ga.core.TargetPolicy(
    net_factory_func=net_factory,
    lr = 1e-3
)

# %%
agent = ga.DQN(
    env_id=env_id,
    policy=dqn_policy,
    config=ga.DQNConfig(
        eps_decay_steps=100000,
        env_kwargs={"max_episode_steps": max_episode_steps},
    )
)
# Out:
# Using device: cpu
# d:\Programming\lab\MATE-main\.venv\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %%
agent.fit(total_timesteps=total_timesteps, save_best=True, save_dir=chkpt_dir, progress_bar=tqdm)
# Out:
#   0%|          | 0/200000 [00:00<?, ?it/s]

# %%
agent = ga.DQN.from_checkpoint(env_id, dqn_policy, chkpt_dir)
# Out:
# Loading checkpoint from D:\Programming\lab\MATE-main\checkpoints\LunarLander-v3\DQN\2026-02-07_22-13-59\last_167.zip
# Using device: cpu

# %%
agent.plot_scores()

# %% [markdown]
# # A2C/PPO

# %%
class Feature_Extractor(nn.Module):
    def __init__(self, n_inp: int, features: list[int] = [256, 256]):
        super().__init__()

        layers = [n_inp] + features

        self.net = nn.Sequential()

        for i in range(len(layers)-1):
            self.net.append(nn.Linear(layers[i], layers[i+1]))
            self.net.append(nn.ReLU())

    def forward(self, X):
        return self.net(X)

# %%
def feature_extractor_factory():
    return Feature_Extractor(
        n_inp=8,
        features=[256, 256]
    )

def actor_factory():
    net = nn.Sequential(
        Feature_Extractor(n_inp=8, features=[256, 256]),
        nn.Linear(256, 4)
    )
    return net

def critic_factory():
    net = nn.Sequential(
        Feature_Extractor(n_inp=8, features=[256, 256]),
        nn.Linear(256, 1)
    )
    return net

# %%
a2c_policy = ga.core.ActorCriticPolicy(
    actor_factory_func=actor_factory,
    critic_factory_func=critic_factory,
    actor_lr=7e-4,
    optim_cls=torch.optim.RMSprop,
    optim_kwargs={"alpha": 0.99, "eps": 1e-5}
)

# %%
agent = ga.A2C(
    env_id=env_id,
    policy=a2c_policy,
    config=ga.A2CConfig(
        num_envs=4,
        n_steps=8,
        entropy_coef=0.01,
        normalize_advantage=False,
        env_kwargs={"max_episode_steps": max_episode_steps},
    )
)
# Out:
# Using device: cpu

# %%
agent.fit(total_timesteps=total_timesteps, save_best=True, save_dir=chkpt_dir, progress_bar=tqdm)
# Out:
#   0%|          | 0/200000 [00:00<?, ?it/s]

# %%
agent = ga.A2C.from_checkpoint(env_id, a2c_policy, chkpt_dir)
# Out:
# Loading checkpoint from D:\Programming\lab\MATE-main\checkpoints\LunarLander-v3\A2C\2026-02-07_22-58-11\last_-190.zip
# Using device: cpu

# %%
agent.plot_scores()

# %%
ppo_policy = ga.core.ActorCriticPolicy(
    actor_factory_func=actor_factory,
    critic_factory_func=critic_factory,
    actor_lr=3e-4,
)

# %%
agent = ga.PPO(
    env_id=env_id,
    policy=ppo_policy,
    config=ga.PPOConfig(
        # num_envs=8,
        n_steps=2048,
        batch_size=64,
        n_epochs=10,
        clip_range=0.2,
        entropy_coef=0.01,
        gae_lambda=0.95,
        gamma=0.99,
        normalize_advantage=True,
        env_kwargs={"max_episode_steps": max_episode_steps},
    )
)
# Out:
# Using device: cpu

# %%
agent.fit(total_timesteps=total_timesteps, save_best=True, save_dir=chkpt_dir, progress_bar=tqdm)
# Out:
#   0%|          | 0/200000 [00:00<?, ?it/s]

# %%
agent = ga.PPO.from_checkpoint(env_id, ppo_policy, chkpt_dir)
# Out:
# Loading checkpoint from D:\Programming\lab\MATE-main\checkpoints\LunarLander-v3\PPO\2026-02-07_23-07-43\last_182.zip
# Using device: cpu

# %%
agent.plot_scores()
